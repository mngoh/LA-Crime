# %% [markdown]
# # Crime Statistics
# ## Date: June 18th 2023
# ### Martin N.

# %%
# Load Libraries
import sys
import os 
import sys
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from functions import plot_funcs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-7ae1e8b583d0> in <module>
#       6 import numpy as np
#       7 import matplotlib.pyplot as plt
# ----> 8 from functions import plot_funcs
#
# ImportError: cannot import name 'plot_funcs' from 'functions' (unknown location)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Load Data
df = pd.read_csv('data/crime_2020_present.csv')

# %%
# EDA 
print(df.head()[:2])
print(len(df))
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd               Crm Cd Desc  ...  \
# 0  Southwest          377         2     624  BATTERY - SIMPLE ASSAULT  ...
# 1    Central          163         2     624  BATTERY - SIMPLE ASSAULT  ...
#
#   Status  Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0     AO  Adult Other    624.0      NaN       NaN      NaN
# 1     IC  Invest Cont    624.0      NaN       NaN      NaN
#
#                                   LOCATION Cross Street      LAT       LON
# 0  1100 W  39TH                         PL          NaN  34.0141 -118.2978
# 1   700 S  HILL                         ST          NaN  34.0459 -118.2545
#
# [2 rows x 28 columns]
# 739687

# %%
# Check Missing Values
df.isna().sum().sort_values(ascending = False)[:13]
# Out:
# Crm Cd 4          739633
# Crm Cd 3          737854
# Crm Cd 2          684857
# Cross Street      620543
# Weapon Used Cd    482961
# Weapon Desc       482961
# Mocodes           101461
# Vict Descent       96578
# Vict Sex           96572
# Premis Desc          421
# Premis Cd             10
# Crm Cd 1               8
# LAT                    0
# dtype: int64

# %%
# Data Types
df.dtypes
# Out:
# DR_NO               int64
# Date Rptd          object
# DATE OCC           object
# TIME OCC            int64
# AREA                int64
# AREA NAME          object
# Rpt Dist No         int64
# Part 1-2            int64
# Crm Cd              int64
# Crm Cd Desc        object
# Mocodes            object
# Vict Age            int64
# Vict Sex           object
# Vict Descent       object
# Premis Cd         float64
# Premis Desc        object
# Weapon Used Cd    float64
# Weapon Desc        object
# Status             object
# Status Desc        object
# Crm Cd 1          float64
# Crm Cd 2          float64
# Crm Cd 3          float64
# Crm Cd 4          float64
# LOCATION           object
# Cross Street       object
# LAT               float64
# LON               float64
# dtype: object

# %%
# Sex Distribution
plt.hist(df['Vict Sex'].dropna())
plt.show()

# %%
%
