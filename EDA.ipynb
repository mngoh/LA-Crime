# %% [markdown]
# # Crime Statistics
# ## Date: June 18th 2023
# ### Martin N.

# %%
# Load Libraries
import sys
import os 
import sys
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import sys

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Load Data
df = pd.read_csv('data/crime_stats_cleaned.csv')

# %%
# EDA 
print(df.head()[:2])
print(len(df))
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  1.928599 -0.735398  0.203659  1.112995  0.294139 -0.440264  0.034718
# 1  1.492070 -1.750910  0.503528  1.433252 -0.054436 -0.866303  0.557295
#
#         PC8       PC9      PC10  vict_age
# 0 -0.405816  0.116360  0.646245  0.280186
# 1  0.252645 -1.690451  0.168735 -0.226268
# 739687

# %%
# Check Missing Values
df.isna().sum().sort_values(ascending = False)[:13]
# Out:
# PC1         0
# PC2         0
# PC3         0
# PC4         0
# PC5         0
# PC6         0
# PC7         0
# PC8         0
# PC9         0
# PC10        0
# vict_age    0
# dtype: int64

# %%
# Data Types
df.dtypes
# Out:
# PC1         float64
# PC2         float64
# PC3         float64
# PC4         float64
# PC5         float64
# PC6         float64
# PC7         float64
# PC8         float64
# PC9         float64
# PC10        float64
# vict_age    float64
# dtype: object

# %%
# Sex Distribution
plt.hist(df['Vict Sex'].dropna())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Vict Sex'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-8fc84cfa7cae> in <module>
# ...
